# %% [markdown]
# <a href="https://colab.research.google.com/github/HenriqueCF8896/MNCM/blob/main/Programa2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import matplotlib.pyplot as plt

def bisection(f, a, b, tol=1e-6, max_iter=1000):
    if f(a) * f(b) >= 0:
        raise ValueError("A função deve ter sinais opostos nos extremos do intervalo.")

    iter_count = 0
    errors = []
    roots = []
    c_prev = None

    while iter_count < max_iter:
        c = (a + b) / 2
        roots.append(c)

        if c_prev is not None:
            error = abs((c - c_prev) / c)
            errors.append(error)
            if error < tol:
                break
        else:
            errors.append(None)

        fc = f(c)

        if fc == 0:
            break

        if f(a) * fc < 0:
            b = c
        else:
            a = c

        c_prev = c
        iter_count += 1

    return roots, iter_count + 1, errors

def false_position(f, a, b, tol=1e-6, max_iter=1000):
    if f(a) * f(b) >= 0:
        raise ValueError("A função deve ter sinais opostos nos extremos do intervalo.")

    iter_count = 0
    errors = []
    roots = []
    c_prev = None

    while iter_count < max_iter:
        fa = f(a)
        fb = f(b)
        c = (a * fb - b * fa) / (fb - fa)
        roots.append(c)

        if c_prev is not None:
            error = abs((c - c_prev) / c)
            errors.append(error)
            if error < tol:
                break
        else:
            errors.append(None)

        fc = f(c)

        if fc == 0:
            break

        if fa * fc < 0:
            b = c
        else:
            a = c

        c_prev = c
        iter_count += 1

    return roots, iter_count + 1, errors

# Definindo as equações e intervalos
equations = [
    {
        'name': '-0.5x³ + 2.5x² + 4.5',
        'f': lambda x: -0.5*x**3 + 2.5*x**2 + 4.5,
        'interval': (5, 10)
    },
    {
        'name': '5x³ -5x² +6x -2',
        'f': lambda x: 5*x**3 -5*x**2 +6*x -2,
        'interval': (0, 1)
    },
    {
        'name': '-25+82x-90x²+44x³-8x⁴+0.7x⁵',
        'f': lambda x: -25 +82*x -90*x**2 +44*x**3 -8*x**4 +0.7*x**5,
        'interval': (0.5, 1)
    },
    {
        'name': 'sin(x) - x³',
        'f': lambda x: math.sin(x) - x**3,
        'interval': (0.5, 1)
    },
    {
        'name': 'ln(x⁴) - 0.7',
        'f': lambda x: math.log(x**4) - 0.7,
        'interval': (0.5, 2)
    }
]

# Parâmetros numéricos
tolerance = 1e-6
max_iterations = 1000

# Processamento para cada equação
for eq in equations:
    print(f"\n{'='*50}")
    print(f"Resolvendo: {eq['name']}")
    print(f"Intervalo inicial: {eq['interval']}\n")

    f = eq['f']
    a, b = eq['interval']

    # Bissecção
    try:
        roots_bis, iter_bis, errors_bis = bisection(f, a, b, tolerance, max_iterations)
        print("Método da Bissecção:")
        print(f"Iterações: {iter_bis}")
        print(f"Raiz aproximada: {roots_bis[-1]:.8f}")
        print("Erro relativo por iteração:")
        for i, err in enumerate(errors_bis):
            print(f"Iteração {i+1}: {err if err is not None else 'N/A'}")
    except ValueError as e:
        print(f"Erro na bissecção: {e}")

    # Falsa Posição
    try:
        roots_fp, iter_fp, errors_fp = false_position(f, a, b, tolerance, max_iterations)
        print("\nMétodo da Falsa Posição:")
        print(f"Iterações: {iter_fp}")
        print(f"Raiz aproximada: {roots_fp[-1]:.8f}")
        print("Erro relativo por iteração:")
        for i, err in enumerate(errors_fp):
            print(f"Iteração {i+1}: {err if err is not None else 'N/A'}")
    except ValueError as e:
        print(f"Erro na falsa posição: {e}")

    # Plotagem comparativa
    plt.figure(figsize=(10, 6))
    valid_bis = [e for e in errors_bis if e is not None]
    valid_fp = [e for e in errors_fp if e is not None]

    plt.plot(range(1, len(valid_bis)+1), valid_bis, 'b-o', label='Bissecção')
    plt.plot(range(1, len(valid_fp)+1), valid_fp, 'r--s', label='Falsa Posição')

    plt.xlabel('Iteração')
    plt.ylabel('Erro Relativo')
    plt.title(f'Comparação de Convergência para: {eq["name"]}')
    plt.yscale('log')
    plt.grid(True)
    plt.legend()
    plt.show()
# Out:
# ==================================================
# Resolvendo: -0.5x³ + 2.5x² + 4.5
# Intervalo inicial: (5, 10)
#
# Método da Bissecção:
# Iterações: 20
# Raiz aproximada: 5.31820774
# Erro relativo por iteração:
# Iteração 1: N/A
# Iteração 2: 0.2
# Iteração 3: 0.1111111111111111
# Iteração 4: 0.058823529411764705
# Iteração 5: 0.02857142857142857
# Iteração 6: 0.014492753623188406
# Iteração 7: 0.0072992700729927005
# Iteração 8: 0.003663003663003663
# Iteração 9: 0.001834862385321101
# Iteração 10: 0.0009182736455463728
# Iteração 11: 0.0004589261128958238
# Iteração 12: 0.00022951572182694515
# Iteração 13: 0.0001147710317915758
# Iteração 14: 5.738222298731853e-05
# Iteração 15: 2.869193469715663e-05
# Iteração 16: 1.4345761544751604e-05
# Iteração 17: 7.172932222963425e-06
# Iteração 18: 3.5864532487886755e-06
# Iteração 19: 1.7932234087383777e-06
# Iteração 20: 8.96612508282458e-07
#
# Método da Falsa Posição:
# Iterações: 29
# Raiz aproximada: 5.31819814
# Erro relativo por iteração:
# Iteração 1: N/A
# Iteração 2: 0.012760263002290672
# Iteração 3: 0.00912257663774583
# Iteração 4: 0.006477223489872132
# Iteração 5: 0.004576174406382215
# Iteração 6: 0.0032216097784109232
# Iteração 7: 0.0022622849529604205
# Iteração 8: 0.0015857959886508952
# Iteração 9: 0.0011102024332835761
# Iteração 10: 0.0007765585898874475
# Iteração 11: 0.0005428476365690188
# Iteração 12: 0.0003793095903461773
# Iteração 13: 0.0002649587709431194
# Iteração 14: 0.0001850422618252503
# Iteração 15: 0.00012921096732425273
# Iteração 16: 9.021588155530178e-05
# Iteração 17: 6.298473527781122e-05
# Iteração 18: 4.3970940782891884e-05
# Iteração 19: 3.069594040232943e-05
# Iteração 20: 2.1428189166831558e-05
# Iteração 21: 1.4958311076951634e-05
# Iteração 22: 1.044177801502085e-05
# Iteração 23: 7.2889123218832384e-06
# Iteração 24: 5.088015963827807e-06
# Iteração 25: 3.5516686161254954e-06
# Iteração 26: 2.4792206290745238e-06
# Iteração 27: 1.7306014179287546e-06
# Iteração 28: 1.2080317052549758e-06
# Iteração 29: 8.43255515808523e-07
# ==================================================
# Resolvendo: 5x³ -5x² +6x -2
# Intervalo inicial: (0, 1)
#
# Método da Bissecção:
# Iterações: 22
# Raiz aproximada: 0.41810060
# Erro relativo por iteração:
# Iteração 1: N/A
# Iteração 2: 1.0
# Iteração 3: 0.3333333333333333
# Iteração 4: 0.14285714285714285
# Iteração 5: 0.07692307692307693
# Iteração 6: 0.037037037037037035
# Iteração 7: 0.018867924528301886
# Iteração 8: 0.009345794392523364
# Iteração 9: 0.004651162790697674
# Iteração 10: 0.002331002331002331
# Iteração 11: 0.0011668611435239206
# Iteração 12: 0.0005837711617046118
# Iteração 13: 0.00029197080291970805
# Iteração 14: 0.00014596409283316303
# Iteração 15: 7.298737318443909e-05
# Iteração 16: 3.649501842998431e-05
# Iteração 17: 1.8247842192660717e-05
# Iteração 18: 9.123837851153709e-06
# Iteração 19: 4.5619397367760775e-06
# Iteração 20: 2.2809646655763656e-06
# Iteração 21: 1.1404836334896176e-06
# Iteração 22: 5.702421419207238e-07
#
# Método da Falsa Posição:
# Iterações: 14
# Raiz aproximada: 0.41810051
# Erro relativo por iteração:
# Iteração 1: N/A
# Iteração 2: 0.14492753623188415
# Iteração 3: 0.04516480744090204
# Iteração 4: 0.015366945145209913
# Iteração 5: 0.005366539709119572
# Iteração 6: 0.0018905343334382513
# Iteração 7: 0.0006680172071526731
# Iteração 8: 0.00023629371866213392
# Iteração 9: 8.361412030966113e-05
# Iteração 10: 2.959134363336546e-05
# Iteração 11: 1.047297652613279e-05
# Iteração 12: 3.7066603191405636e-06
# Iteração 13: 1.311891748824621e-06
# Iteração 14: 4.6431649863983505e-07
# ==================================================
# Resolvendo: -25+82x-90x²+44x³-8x⁴+0.7x⁵
# Intervalo inicial: (0.5, 1)
#
# Método da Bissecção:
# Iterações: 20
# Raiz aproximada: 0.57940912
# Erro relativo por iteração:
# Iteração 1: N/A
# Iteração 2: 0.2
# Iteração 3: 0.1111111111111111
# Iteração 4: 0.05263157894736842
# Iteração 5: 0.02702702702702703
# Iteração 6: 0.013333333333333334
# Iteração 7: 0.006711409395973154
# Iteração 8: 0.003367003367003367
# Iteração 9: 0.0016863406408094434
# Iteração 10: 0.0008424599831508003
# Iteração 11: 0.00042140750105351877
# Iteração 12: 0.0002106593638087213
# Iteração 13: 0.00010534077741493732
# Iteração 14: 5.2667614683730974e-05
# Iteração 15: 2.6334500829536777e-05
# Iteração 16: 1.3167423793534795e-05
# Iteração 17: 6.583755242315112e-06
# Iteração 18: 3.291888457651501e-06
# Iteração 19: 1.6459415196978052e-06
# Iteração 20: 8.229714371303315e-07
#
# Método da Falsa Posição:
# Iterações: 8
# Raiz aproximada: 0.57940938
# Erro relativo por iteração:
# Iteração 1: N/A
# Iteração 2: 0.0930426028293116
# Iteração 3: 0.012885192307939563
# Iteração 4: 0.0016919782782566747
# Iteração 5: 0.00022052516629706768
# Iteração 6: 2.8714121554005908e-05
# Iteração 7: 3.738327799613475e-06
# Iteração 8: 4.866895208926931e-07
# ==================================================
# Resolvendo: sin(x) - x³
# Intervalo inicial: (0.5, 1)
#
# Método da Bissecção:
# Iterações: 20
# Raiz aproximada: 0.92862654
# Erro relativo por iteração:
# Iteração 1: N/A
# Iteração 2: 0.14285714285714285
# Iteração 3: 0.06666666666666667
# Iteração 4: 0.034482758620689655
# Iteração 5: 0.01694915254237288
# Iteração 6: 0.008403361344537815
# Iteração 7: 0.004219409282700422
# Iteração 8: 0.002105263157894737
# Iteração 9: 0.0010515247108307045
# Iteração 10: 0.0005260389268805891
# Iteração 11: 0.00026295030239284776
# Iteração 12: 0.00013145786775338504
# Iteração 13: 6.572461386789353e-05
# Iteração 14: 3.2863386900653985e-05
# Iteração 15: 1.6431423454213838e-05
# Iteração 16: 8.21577922558065e-06
# Iteração 17: 4.107906487616716e-06
# Iteração 18: 2.053949025093095e-06
# Iteração 19: 1.0269734578709814e-06
# Iteração 20: 5.134864652670053e-07
#
# Método da Falsa Posição:
# Iterações: 8
# Raiz aproximada: 0.92862630
# Erro relativo por iteração:
# Iteração 1: N/A
# Iteração 2: 0.08001059339734194
# Iteração 3: 0.009272385720197715
# Iteração 4: 0.0009836088633941673
# Iteração 5: 0.00010330732511829813
# Iteração 6: 1.0838841068419758e-05
# Iteração 7: 1.1370684353925954e-06
# Iteração 8: 1.1928486021649635e-07
# ==================================================
# Resolvendo: ln(x⁴) - 0.7
# Intervalo inicial: (0.5, 2)
#
# Método da Bissecção:
# Iterações: 21
# Raiz aproximada: 1.19124675
# Erro relativo por iteração:
# Iteração 1: N/A
# Iteração 2: 0.42857142857142855
# Iteração 3: 0.17647058823529413
# Iteração 4: 0.08108108108108109
# Iteração 5: 0.03896103896103896
# Iteração 6: 0.019867549668874173
# Iteração 7: 0.009836065573770493
# Iteração 8: 0.004942339373970346
# Iteração 9: 0.0024650780608052587
# Iteração 10: 0.0012310217480508822
# Iteração 11: 0.0006151322534344885
# Iteração 12: 0.00030747155888080353
# Iteração 13: 0.00015371214838346057
# Iteração 14: 7.685016778953301e-05
# Iteração 15: 3.842656043857514e-05
# Iteração 16: 1.9213649376517078e-05
# Iteração 17: 9.606732398064563e-06
# Iteração 18: 4.803389271469949e-06
# Iteração 19: 2.4017004038859513e-06
# Iteração 20: 1.2008516439859148e-06
# Iteração 21: 6.004261825043416e-07
#
# Método da Falsa Posição:
# Iterações: 13
# Raiz aproximada: 1.19124664
# Erro relativo por iteração:
# Iteração 1: N/A
# Iteração 2: 0.13221583031236184
# Iteração 3: 0.04413659202739157
# Iteração 4: 0.014665815543004357
# Iteração 5: 0.004866388588275516
# Iteração 6: 0.001614036338122297
# Iteração 7: 0.000535249542775264
# Iteração 8: 0.00017749181386833305
# Iteração 9: 5.885636081293393e-05
# Iteração 10: 1.9516690784758978e-05
# Iteração 11: 6.471697274809469e-06
# Iteração 12: 2.1460011673459613e-06
# Iteração 13: 7.116093238251819e-07
